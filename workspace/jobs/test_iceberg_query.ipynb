# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("Test_Iceberg_Query").getOrCreate()

print("=== 10 SẢN PHẨM MỚI NHẤT TRONG ICEBERG ===")
query_1 = """
    SELECT id, name, price, brand_name, crawl_date 
    FROM local_catalog.tiki.products 
    LIMIT 10
"""
spark.sql(query_1).show()

print("=== THỐNG KÊ SỐ LƯỢNG THEO DANH MỤC ===")
query_2 = """
    SELECT category_id, COUNT(id) as total_products 
    FROM local_catalog.tiki.products 
    GROUP BY category_id
    order by total_products desc
"""
spark.sql(query_2).show()
# Out:
# === 10 SẢN PHẨM MỚI NHẤT TRONG ICEBERG ===
# +------+--------------------+-------+--------------+----------+
# |    id|                name|  price|    brand_name|crawl_date|
# +------+--------------------+-------+--------------+----------+
# |384886|Xà Phòng Thiên nh...|  45000|         AN'Sw|2026-05-14|
# |385582|Bao cao su Durex ...| 195000|         Durex|2026-05-14|
# |385615|Bao cao su Durex ...| 195000|         Durex|2026-05-14|
# |386737|Dầu Gội Chăm Sóc ...| 175000|       Pantene|2026-05-14|
# |389598|Bao Cao Su Sagami...| 441000|        Sagami|2026-05-14|
# |416637|Máy Đo Huyết Áp B...|1200000|        Beurer|2026-05-14|
# |442283|Máy Đo Huyết Áp B...| 845000|     Microlife|2026-05-14|
# |442864|Đèn Phun Tinh Dầu...|1070000|        Beurer|2026-05-14|
# |470554|Gel Tắm Làm Dịu, ...| 540000|La Roche-Posay|2026-05-14|
# |470571|Kem chống nắng dạ...| 375000|La Roche-Posay|2026-05-14|
# +------+--------------------+-------+--------------+----------+
#
# === THỐNG KÊ SỐ LƯỢNG THEO DANH MỤC ===
# +-----------+--------------+
# |category_id|total_products|
# +-----------+--------------+
# |       8602|          1069|
# |      11935|           798|
# |       1583|           667|
# |       1630|           655|
# |       3422|           494|
# |       1636|           469|
# |       1622|           435|
# |       8172|           372|
# |      11873|           361|
# |       1613|           330|
# |       2342|           318|
# |      11885|           305|
# |      11605|           305|
# |       8208|           282|
# |       8305|           270|
# |      11669|           267|
# |       7064|           263|
# |       1598|           259|
# |       1637|           255|
# |      11697|           253|
# +-----------+--------------+
# only showing top 20 rows

# %%
spark.sql("DROP TABLE IF EXISTS local_catalog.tiki.products")
# Out:
# DataFrame[]

# %%
spark.sql("select count(*) from local_catalog.tiki.products").show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |   19356|
# +--------+

# %%
spark.sql("select * from local_catalog.tiki.products").show()
# Out:
# +------+-------------+--------------------+--------------------+-------+--------------+--------+-------------+--------------+--------------+------------+--------------------+-----------+-------------+----------+
# |    id|          sku|                name|             url_key|  price|original_price|discount|discount_rate|    brand_name|rating_average|review_count|       thumbnail_url|category_id|quantity_sold|crawl_date|
# +------+-------------+--------------------+--------------------+-------+--------------+--------+-------------+--------------+--------------+------------+--------------------+-----------+-------------+----------+
# |384886|5854768860384|Xà Phòng Thiên nh...|xa-phong-thien-nh...|  45000|         45000|       0|            0|         AN'Sw|           4.0|           4|https://salt.tiki...|      13878|          100|2026-05-14|
# |385582|8850163100107|Bao cao su Durex ...|bao-cao-su-durex-...| 195000|        370920|  175920|           47|         Durex|           4.7|         219|https://salt.tiki...|       1630|        30294|2026-05-14|
# |385615|5038483234167|Bao cao su Durex ...|bao-cao-su-durex-...| 195000|        280000|   85000|           30|         Durex|           4.5|         187|https://salt.tiki...|       1630|         8920|2026-05-14|
# |386737|4902430467759|Dầu Gội Chăm Sóc ...|dau-goi-cham-soc-...| 175000|        227000|   52000|           23|       Pantene|           3.4|           5|https://salt.tiki...|       1613|         1130|2026-05-14|
# |389598|1985697609059|Bao Cao Su Sagami...|bao-cao-su-sagami...| 441000|        441000|       0|            0|        Sagami|           5.0|           6|https://salt.tiki...|       1630|          114|2026-05-14|
# |416637|1111299146661|Máy Đo Huyết Áp B...|may-do-huyet-ap-b...|1200000|       1200000|       0|            0|        Beurer|           0.0|           0|https://salt.tiki...|       8168|            1|2026-05-14|
# |442283|3905547154780|Máy Đo Huyết Áp B...|may-do-huyet-ap-b...| 845000|        845000|       0|            0|     Microlife|           5.0|          17|https://salt.tiki...|       8168|           61|2026-05-14|
# |442864|7858780100583|Đèn Phun Tinh Dầu...|den-phun-tinh-dau...|1070000|       1070000|       0|            0|        Beurer|           0.0|           0|https://salt.tiki...|       8225|            3|2026-05-14|
# |470554|9740541936697|Gel Tắm Làm Dịu, ...|gel-tam-lam-diu-b...| 540000|        540000|       0|            0|La Roche-Posay|           0.0|           0|https://salt.tiki...|       1598|            5|2026-05-14|
# |470571|6821340756235|Kem chống nắng dạ...|kem-chong-nang-da...| 375000|        375000|       0|            0|La Roche-Posay|           3.6|           8|https://salt.tiki...|       3422|           39|2026-05-14|
# |470616|6805418869672|Kem Dưỡng Môi Phụ...|kem-duong-moi-phu...| 595000|        595000|       0|            0|La Roche-Posay|           0.0|           0|https://salt.tiki...|      68337|            7|2026-05-14|
# |486711|9655253434068|Xịt Khoáng Tinh C...|xit-khoang-tinh-c...|  75000|         75000|       0|            0|       Aspasia|           5.0|           2|https://salt.tiki...|       5872|           21|2026-05-14|
# |505636|8935212800068|Dầu Gội Dưỡng Tóc...|dau-goi-duong-toc...| 167000|        206000|   39000|           19|    Enchanteur|           4.5|          15|https://salt.tiki...|       1613|        18039|2026-05-14|
# |505645|8935212805162|Dầu Gội Dưỡng Tóc...|dau-goi-duong-toc...| 167000|        206000|   39000|           19|    Enchanteur|           4.8|          16|https://salt.tiki...|       1613|        10185|2026-05-14|
# |523011|3950626487945|Kem Dưỡng Ẩm Dành...|kem-duong-am-danh...| 415000|        415000|       0|            0|           SVR|           5.0|           1|https://salt.tiki...|      11697|            8|2026-05-14|
# |525401|8935212810074|Sữa Tắm Romano Cl...|sua-tam-romano-cl...| 170000|        204000|   34000|           17|        Romano|           4.3|          14|https://salt.tiki...|       1598|         8159|2026-05-14|
# |525402|8935212810821|Sữa Tắm Romano Fo...|sua-tam-romano-fo...| 123000|        204000|   81000|           40|        Romano|           5.0|          15|https://salt.tiki...|       1598|          739|2026-05-14|
# |538423|8140855122748|Máy Đo Đường Huyế...|may-do-duong-huye...| 658000|        658000|       0|            0|        OGCARE|           4.8|          12|https://salt.tiki...|      11905|           23|2026-05-14|
# |541546|6839390433678|Bao Cao Su Okamot...|bao-cao-su-okamot...| 150000|        150000|       0|            0|       Okamoto|           0.0|           0|https://salt.tiki...|       1630|           12|2026-05-14|
# |542967|4902430432795|Dầu Xả Pantene Ng...|dau-xa-pantene-ng...| 175000|        227000|   52000|           23|       Pantene|           5.0|           1|https://salt.tiki...|       1616|         1334|2026-05-14|
# +------+-------------+--------------------+--------------------+-------+--------------+--------+-------------+--------------+--------------+------------+--------------------+-----------+-------------+----------+
# only showing top 20 rows

# %%
query = """
        select brand_name, round(avg(price), 2)
        from local_catalog.tiki.products
        group by brand_name
"""
spark.sql(query).show()
# Out:
# +--------------------+--------------------+
# |          brand_name|round(avg(price), 2)|
# +--------------------+--------------------+
# |               JOBST|          1432363.64|
# |             Pocheon|            798500.0|
# |        Salon de Pro|           208823.53|
# |             Gintell|          1666665.67|
# |              L ORCA|           1525000.0|
# |           Dermarium|           465923.08|
# |            miDoctor|            135000.0|
# |               Shian|            106000.0|
# |         Hương Thiền|            125000.0|
# |               DISAN|           841818.18|
# |               Peppy|           231679.38|
# |    Lactobact Intima|            679400.0|
# |             ShieldX|            169500.0|
# |            Palmer's|            474050.0|
# |Rừng Nhiệt Đới TR...|            256500.0|
# |          Black Rose|            275000.0|
# |           Shinpoong|           584142.86|
# |            H2ofloss|           358833.33|
# |            Kingphar|           113983.86|
# |      Hena Happy Oil|             52500.0|
# +--------------------+--------------------+
# only showing top 20 rows

# %%
query = """
        select count(distinct brand_name) as count_brand
        from local_catalog.tiki.products
"""
spark.sql(query).show()
# Out:
# +-----------+
# |count_brand|
# +-----------+
# |       2239|
# +-----------+

# %%
query = """
        select count(*) as count_product_of_durex
        from local_catalog.tiki.products
        where brand_name = 'Durex'
"""
spark.sql(query).show()
# Out:
# +----------------------+
# |count_product_of_durex|
# +----------------------+
# |                   134|
# +----------------------+

# %%
print("=== DANH SÁCH DATABASE ===")
spark.sql("SHOW DATABASES IN local_catalog").show(truncate=False)
# Out:
# === DANH SÁCH DATABASE ===
# +---------+
# |namespace|
# +---------+
# |default  |
# |tiki     |
# +---------+

# %%
print("=== DANH SÁCH CÁC BẢNG TRONG TIKI ===")
spark.sql("SHOW TABLES IN local_catalog.tiki").show(truncate=False)
# Out:
# === DANH SÁCH CÁC BẢNG TRONG TIKI ===
# +---------+---------+-----------+
# |namespace|tableName|isTemporary|
# +---------+---------+-----------+
# |tiki     |products |false      |
# +---------+---------+-----------+

# %%
print("=== CẤU TRÚC BẢNG PRODUCTS ===")
spark.sql("DESCRIBE local_catalog.tiki.products").show(truncate=False)
# Out:
# === CẤU TRÚC BẢNG PRODUCTS ===
# +-----------------------+---------+-------+
# |col_name               |data_type|comment|
# +-----------------------+---------+-------+
# |id                     |bigint   |NULL   |
# |sku                    |string   |NULL   |
# |name                   |string   |NULL   |
# |url_key                |string   |NULL   |
# |price                  |bigint   |NULL   |
# |original_price         |bigint   |NULL   |
# |discount               |bigint   |NULL   |
# |discount_rate          |int      |NULL   |
# |brand_name             |string   |NULL   |
# |rating_average         |double   |NULL   |
# |review_count           |int      |NULL   |
# |thumbnail_url          |string   |NULL   |
# |category_id            |int      |NULL   |
# |quantity_sold          |int      |NULL   |
# |crawl_date             |date     |NULL   |
# |# Partition Information|         |       |
# |# col_name             |data_type|comment|
# |crawl_date             |date     |NULL   |
# +-----------------------+---------+-------+

# %%
print("=== LỊCH SỬ CÁC LẦN GHI DỮ LIỆU ===")
spark.sql("SELECT * FROM local_catalog.tiki.products.history").show(truncate=False)

print("=== CHI TIẾT SNAPSHOTS ===")
spark.sql("SELECT committed_at, snapshot_id, operation FROM local_catalog.tiki.products.snapshots").show(truncate=False)
# Out:
# === LỊCH SỬ CÁC LẦN GHI DỮ LIỆU ===
# +-----------------------+-------------------+-------------------+-------------------+
# |made_current_at        |snapshot_id        |parent_id          |is_current_ancestor|
# +-----------------------+-------------------+-------------------+-------------------+
# |2026-05-14 18:31:49.608|4858032061281437762|NULL               |true               |
# |2026-05-14 19:07:06.014|3528707343059081567|4858032061281437762|true               |
# +-----------------------+-------------------+-------------------+-------------------+
#
# === CHI TIẾT SNAPSHOTS ===
# +-----------------------+-------------------+---------+
# |committed_at           |snapshot_id        |operation|
# +-----------------------+-------------------+---------+
# |2026-05-14 18:31:49.608|4858032061281437762|append   |
# |2026-05-14 19:07:06.014|3528707343059081567|overwrite|
# +-----------------------+-------------------+---------+

# %%
spark.sql("""
    SELECT count(id) as so_sp_bien_dong, crawl_date 
    FROM local_catalog.tiki.price_history 
    WHERE crawl_date = '2026-05-15'
    GROUP BY crawl_date
""").show()
# Out:
# +---------------+----------+
# |so_sp_bien_dong|crawl_date|
# +---------------+----------+
# |            495|2026-05-15|
# +---------------+----------+

# %%
spark.sql("""
    select a.id, b.name, b.price as new_price, a.price as old_price
    from local_catalog.tiki.price_history a
    join local_catalog.tiki.products b
    on a.id = b.id
""").show()
# Out:
# +---------+--------------------+---------+---------+
# |       id|                name|new_price|old_price|
# +---------+--------------------+---------+---------+
# |   505645|Dầu Gội Dưỡng Tóc...|   134000|   134000|
# |   525402|Sữa Tắm Romano Fo...|    98000|    98000|
# |   580690|Lăn Khử Mùi Cao C...|    64000|    64000|
# |   580785|Lăn Khử Mùi Trắng...|    62000|    62000|
# | 12504646|Sữa tắm Romano Ge...|   119000|   119000|
# | 15823487|Dung dịch dưỡng ẩ...|   115000|   115000|
# | 16329091|Chiết Xuất Nhung ...|   969000|   969000|
# | 21031108|Sữa tắm xích rồng...|   185000|   185000|
# | 29207744|Kiếng Soi Không M...|   110000|   110000|
# | 52403861|Viên Uống Tinh Ch...|   225000|   225000|
# | 54417619|Nước Tẩy Trang NI...|    98000|    98000|
# | 55339097|Bộ đôi Kem chống ...|   455000|   455000|
# | 76775262|Bộ 2 Dầu gội xả 2...|   193000|   193000|
# |196343045|Viên Uống Bổ Sung...|   230000|   230000|
# |270691423|Viên Uống Vitamin...|  1114000|  1114000|
# |273354497|[Bộ 2] Kem Đánh R...|   122000|   122000|
# |273455565|Lăn Ngăn Mùi NIVE...|    66000|    66000|
# |274189021|VSM- Chiết Xuất N...|   969000|   969000|
# |274506630|Ủ tóc cao cấp FIN...|   115000|   115000|
# |275798196|Dầu xả siêu dưỡng...|   126000|   126000|
# +---------+--------------------+---------+---------+
# only showing top 20 rows

# %%
spark.sql("""
    select * from local_catalog.tiki.price_history 
    where crawl_date = '2026-05-14'
""").show()
# Out:
# +---+-----+----------+
# | id|price|crawl_date|
# +---+-----+----------+
# +---+-----+----------+

# %%
spark.sql("""
    SELECT count(*) as so_luong_sp_moi 
    FROM local_catalog.tiki.price_history 
    WHERE crawl_date = '2026-05-15'
""").show()
# Out:
# +---------------+
# |so_luong_sp_moi|
# +---------------+
# |            495|
# +---------------+

# %%
spark.sql("""
    SELECT count(*) as so_luong_sp_moi 
    FROM local_catalog.tiki.price_history 
""").show()
# Out:
# +---------------+
# |so_luong_sp_moi|
# +---------------+
# |            495|
# +---------------+

# %%
spark.sql("""
    SELECT count(*) as so_luong_sp
    FROM local_catalog.tiki.products
""").show()
# Out:
# +-----------+
# |so_luong_sp|
# +-----------+
# |      19403|
# +-----------+

# %%
spark.sql("""
    SELECT 
        a.id, 
        b.name, 
        a.price as gia_ghi_nhan_cdc,
        b.price as gia_goc
    FROM local_catalog.tiki.price_history a
    JOIN local_catalog.tiki.products b ON a.id = b.id
    WHERE a.crawl_date = '2026-05-15'
""").show(50, truncate=False)
# Out:
# +---------+------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+-------+
# |id       |name                                                                                                                                                        |gia_ghi_nhan_cdc|gia_goc|
# +---------+------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+-------+
# |505645   |Dầu Gội Dưỡng Tóc Siêu Mượt Enchanteur Sensation Chai 650g                                                                                                  |134000          |134000 |
# |525402   |Sữa Tắm Romano Force 650g                                                                                                                                   |98000           |98000  |
# |580690   |Lăn Khử Mùi Cao Cấp Enchanteur Charming 50ml - 1012044                                                                                                      |64000           |64000  |
# |580785   |Lăn Khử Mùi Trắng Da Hương Nước Hoa Enchanteur Sensation 50ml - 1012075                                                                                     |62000           |62000  |
# |12504646 |Sữa tắm Romano Gentleman                                                                                                                                    |119000          |119000 |
# |15823487 |Dung dịch dưỡng ẩm tối ưu Hada Labo Advanced Nourish Lotion dùng cho da thường và da khô 100ml                                                              |115000          |115000 |
# |16329091 |Chiết Xuất Nhung Hươu Và Hồng Sâm Hàn Quốc 6 Năm Tuổi - Giao nhanh 2h                                                                                       |969000          |969000 |
# |21031108 |Sữa tắm xích rồng đỏ Tesori d'Oriente Dragone 250ml + Móc khóa                                                                                              |185000          |185000 |
# |29207744 |Kiếng Soi Không Mờ Suction Mirror Fog Resistant Uncle Bills                                                                                                 |110000          |110000 |
# |52403861 |Viên Uống Tinh Chất Nghệ Giảm Đau Dạ Dày Novacurmin - Nguyên liệu nhập khẩu từ Đức (Hộp 30 viên)                                                            |225000          |225000 |
# |54417619 |Nước Tẩy Trang NIVEA Pearl Radiant Sáng Da | Sạch Sâu (200 ml) - 84911                                                                                      |98000           |98000  |
# |55339097 |Bộ đôi Kem chống nắng dạng xịt dưỡng da bảo vệ hoàn hảo + Kem chống nắng dạng sữa dưỡng da kiềm dầu bảo vệ hoàn hảo (Anessa Gold Spray 60g + Gold Milk 20ml)|455000          |455000 |
# |76775262 |Bộ 2 Dầu gội xả 2in1 Palmolive thiên nhiên 600ml                                                                                                            |193000          |193000 |
# |196343045|Viên Uống Bổ Sung Vitamin C Blackmores Bio C 1000mg Lọ 31 Viên                                                                                              |230000          |230000 |
# |270691423|Viên Uống Vitamin C Chống Oxy Hóa, Tăng Cường Miễn Dịch Codeage Liposomal Vitamin C (180 Viên)                                                              |1114000         |1114000|
# |273354497|[Bộ 2] Kem Đánh Răng Sensodyne Cool Gel 160g/tuýp                                                                                                           |122000          |122000 |
# |273455565|Lăn Ngăn Mùi NIVEA Pearl & Beauty Ngọc Trai Quyến Rũ (50ml) - 83735                                                                                         |66000           |66000  |
# |274189021|VSM- Chiết Xuất Nhung Hươu Và Hồng Sâm Hàn Quốc 6 Năm Tuổi - Ginseng House Hộp 30 gói                                                                       |969000          |969000 |
# |274506630|Ủ tóc cao cấp FINO Premium Touch 230g                                                                                                                       |115000          |115000 |
# |275798196|Dầu xả siêu dưỡng, phục hồi, không chứa silicone salon link 1000ml/chai                                                                                     |126000          |126000 |
# |275798262|Dầu massage cho bé s select 300ml/chai                                                                                                                      |93000           |93000  |
# |275904954|Bộ 2 Băng đêm dạng quần Diana size M-L 5 chiếc/gói                                                                                                          |135000          |135000 |
# |275905053|[MỚI] Băng vệ sinh quần Diana chống tràn 360 size M-L (12 miếng/ gói)                                                                                      |138000          |138000 |
# |275915944|Nước tẩy trang simple Sạch sâu 400ml water boost                                                                                                            |116000          |116000 |
# |275925899|Sáp Khử Mùi Enchanteur Sáng Da 40g                                                                                                                          |62000           |62000  |
# |275967828|Sữa rửa mặt nghệ Hưng Yên Cocoon 310ml                                                                                                                      |201000          |201000 |
# |275969204|Nước bí đao cân bằng da (toner) Cocoon 140ml                                                                                                                |130000          |130000 |
# |275969886|Tinh chất nghệ Hưng Yên C22 với 22% vitamin C sáng da chuyên sâu & mờ vết thâm Cocoon 30ml                                                                  |260000          |260000 |
# |275970349|Thạch hoa hồng dưỡng ẩm Cocoon 30ml                                                                                                                         |118000          |118000 |
# |275970381|Xịt khoáng nghệ Hưng Yên Cocoon 130ml                                                                                                                       |143000          |143000 |
# |276112759|Sữa rửa mặt PERFECT DIARY axit amin tạo bọt dịu nhẹ cho da nhạy cảm 200ml                                                                                   |175000          |175000 |
# |276242808|[PHIÊN BẢN NÂNG CẤP] Xịt Giảm Mụn Lưng Sáng Da Cơ Thể Angel's Liquid Glutathione+ Spot Care Body Mist 150ml                                                 |275000          |275000 |
# |276380327|Combo 10 Mặt Nạ Cấp Ẩm Cấp Tốc Dr.WonJin Instant Repair Hyal Moisture Solution Mask 30g                                                                     |299000          |299000 |
# |277807785|Tẩy Tế Bào Chết Toàn Thân Enchanteur Hương Hoa Lavender 250g                                                                                                |64000           |64000  |
# |278015965|DẦU DƯỠNG TÓC FINO CAO CẤP AIRY SMOOTH 70ml                                                                                                                 |150000          |150000 |
# |278371175|Combo 2 Kem Đánh Răng P/S Ngừa Sâu Răng Vượt Trội 230G                                                                                                      |53000           |53000  |
# |278399698|Set Tinh Chất Chống Nắng Chống Lão Hóa Làm Dịu Da The Whoo UV Ultimate Red Vitamin Suncreen SPF 50+/PA++++ 50ml                                             |1098000         |1098000|
# |278445458|Kem chống nắng Oribe Radiant Derma Shield SPF 50+ PA++++ chống tia UVA/UVB ánh sáng xanh dành cho mọi loại da                                               |309000          |309000 |
# |278485778|Giảm Stress, Đau Nhức: Máy Massge 3D Hỗ Trợ Cổ Vai Gáy Đa Năng Loại Tốt, Lựa Chọn Hàng Đầu Cho Sức Khỏe, ĐÈN TRANG TRÍ                                      |148000          |148000 |
# |278524245|Bộ Đôi Kem Đánh Răng Colgate Ngừa Sâu Răng Tối Đa 225G                                                                                                      |58000           |58000  |
# |278524373|Bộ 2 Bàn Chải Colgate Trắng Răng Optic White                                                                                                                |119000          |119000 |
# |278630481|Dầu Xả Tsubaki Sạch Dầu Mát Lạnh 450ml (Mới)                                                                                                                |136000          |136000 |
# |278998871|Sữa rửa mặt sen Hậu Giang Cocoon 310ml                                                                                                                      |338727          |338727 |
# |279106209|Phấn Mistine Top Country TALC                                                                                                                               |26000           |26000  |
# |279382775|SERUM NÁM - Nubiance. Paris HRB-3 Anti Dark Spot Serum 30mL                                                                                                 |1829000         |1829000|
# |505636   |Dầu Gội Dưỡng Tóc Siêu Mượt Enchanteur Charming Chai 650g                                                                                                   |134000          |134000 |
# |525401   |Sữa Tắm Romano Classic 650g                                                                                                                                 |136000          |136000 |
# |580705   |Lăn Khử Mùi Trắng Da Enchanteur Magic 50ml - 1012059                                                                                                        |58000           |58000  |
# |1313873  |Kem chống nắng Sunplay mát lạnh giải nhiệt dạng sữa Sunplay Super Cool SPF 50, PA++++ 30g                                                                   |79000           |79000  |
# |1313877  |Kem chống nắng Sunplay cho bé từ 6 tháng tuổi và da nhạy cảm, dạng sữa Sunplay Baby Mild SPF 35, PA++ 30g                                                   |86000           |86000  |
# +---------+------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+-------+
# only showing top 50 rows
